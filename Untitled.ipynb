# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt 
# %matplotlib inline

# %%
data = pd.read_excel('tbl_rtddi.xlsx',index_col=0)
print(data)
# Out:
#           DEAD_YEAR(Budha)  DEAD_YEAR   Age  Sex BirthYear  NationalityId  \
# id
# 8722010               2559       2016  47.0  1.0       NaN            NaN
# 8722006               2559       2016  48.0  1.0       NaN            NaN
# 8722013               2559       2016  48.0  1.0       NaN            NaN
# 8722017               2559       2016  48.0  1.0       NaN            NaN
# 8721975               2559       2016  49.0  1.0       NaN            NaN
# ...                    ...        ...   ...  ...       ...            ...
# 10111398              2562       2019  33.0  NaN       NaN            NaN
# 10112013              2562       2019  39.0  NaN       NaN            NaN
# 10111873              2562       2019  77.0  NaN       NaN            NaN
# 10111779              2562       2019   NaN  NaN       NaN            NaN
# 10111864              2562       2019  15.0  NaN       NaN            NaN
#
#          Tumbol           District       Province  RiskHelmet  ...    DateRec  \
# id                                                             ...
# 8722010     NaN                NaN            NaN         NaN  ...        NaT
# 8722006     NaN                NaN            NaN         NaN  ...        NaT
# 8722013     NaN                NaN            NaN         NaN  ...        NaT
# 8722017     NaN                NaN            NaN         NaN  ...        NaT
# 8721975     NaN                NaN            NaN         NaN  ...        NaT
# ...         ...                ...            ...         ...  ...        ...
# 10111398    NaN        เมืองภูเก็ต         ภูเก็ต         NaN  ... 2019-06-29
# 10112013    NaN               สิชล  นครศรีธรรมราช         NaN  ... 2019-09-23
# 10111873    NaN  เมืองสุราษฎร์ธานี   สุราษฎร์ธานี         NaN  ... 2019-10-06
# 10111779    NaN         เมืองระนอง          ระนอง         NaN  ... 2019-12-31
# 10111864    NaN         เมืองระนอง          ระนอง         NaN  ... 2019-12-31
#
#            TimeRec  AccSubDist      AccDist       AccProv    AccLat  \
# id
# 8722010        NaN         NaN          NaN      พิษณุโลก       NaN
# 8722006        NaN         NaN          NaN      พิษณุโลก       NaN
# 8722013        NaN         NaN          NaN      พิษณุโลก       NaN
# 8722017        NaN         NaN          NaN      พิษณุโลก       NaN
# 8721975        NaN         NaN          NaN      พิษณุโลก       NaN
# ...            ...         ...          ...           ...       ...
# 10111398  20:30:00        ฉลอง  เมืองภูเก็ต        ภูเก็ต  7.846704
# 10112013  14:20:00        ฉลอง         สิชล  สุราษฎร์ธานี  8.899548
# 10111873  17:25:00  ท่าทองใหม่   กาญจนดิษฐ์  สุราษฎร์ธานี  9.174437
# 10111779  23:40:00     บางริ้น   เมืองระนอง         ระนอง  9.935354
# 10111864  23:40:00     บางริ้น   เมืองระนอง         ระนอง  9.935354
#
#             AccLong  ICD-10        Vehicle people
# id
# 8722010         NaN    V892   ไม่ระบุพาหนะ      1
# 8722006         NaN    V892   ไม่ระบุพาหนะ      1
# 8722013         NaN    V892   ไม่ระบุพาหนะ      1
# 8722017         NaN    V892   ไม่ระบุพาหนะ      1
# 8721975         NaN    V892   ไม่ระบุพาหนะ      1
# ...             ...     ...            ...    ...
# 10111398  98.336526     NaN  รถจักรยานยนต์      1
# 10112013  99.795811     NaN  รถจักรยานยนต์      1
# 10111873  99.397227     NaN  รถจักรยานยนต์      1
# 10111779  98.633255     NaN  รถจักรยานยนต์      1
# 10111864  98.633255     NaN  รถจักรยานยนต์      1
#
# [223545 rows x 22 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of           DEAD_YEAR(Budha)  DEAD_YEAR   Age  Sex BirthYear  NationalityId  \
# id
# 8722010               2559       2016  47.0  1.0       NaN            NaN
# 8722006               2559       2016  48.0  1.0       NaN            NaN
# 8722013               2559       2016  48.0  1.0       NaN            NaN
# 8722017               2559       2016  48.0  1.0       NaN            NaN
# 8721975               2559       2016  49.0  1.0       NaN            NaN
# ...                    ...        ...   ...  ...       ...            ...
# 10111398              2562       2019  33.0  NaN       NaN            NaN
# 10112013              2562       2019  39.0  NaN       NaN            NaN
# 10111873              2562       2019  77.0  NaN       NaN            NaN
# 10111779              2562       2019   NaN  NaN       NaN            NaN
# 10111864              2562       2019  15.0  NaN       NaN            NaN
#
#          Tumbol           District       Province  RiskHelmet  ...    DateRec  \
# id                                                             ...
# 8722010     NaN                NaN            NaN         NaN  ...        NaT
# 8722006     NaN                NaN            NaN         NaN  ...        NaT
# 8722013     NaN                NaN            NaN         NaN  ...        NaT
# 8722017     NaN                NaN            NaN         NaN  ...        NaT
# 8721975     NaN                NaN            NaN         NaN  ...        NaT
# ...         ...                ...            ...         ...  ...        ...
# 10111398    NaN        เมืองภูเก็ต         ภูเก็ต         NaN  ... 2019-06-29
# 10112013    NaN               สิชล  นครศรีธรรมราช         NaN  ... 2019-09-23
# 10111873    NaN  เมืองสุราษฎร์ธานี   สุราษฎร์ธานี         NaN  ... 2019-10-06
# 10111779    NaN         เมืองระนอง          ระนอง         NaN  ... 2019-12-31
# 10111864    NaN         เมืองระนอง          ระนอง         NaN  ... 2019-12-31
#
#            TimeRec  AccSubDist      AccDist       AccProv    AccLat  \
# id
# 8722010        NaN         NaN          NaN      พิษณุโลก       NaN
# 8722006        NaN         NaN          NaN      พิษณุโลก       NaN
# 8722013        NaN         NaN          NaN      พิษณุโลก       NaN
# 8722017        NaN         NaN          NaN      พิษณุโลก       NaN
# 8721975        NaN         NaN          NaN      พิษณุโลก       NaN
# ...            ...         ...          ...           ...       ...
# 10111398  20:30:00        ฉลอง  เมืองภูเก็ต        ภูเก็ต  7.846704
# 10112013  14:20:00        ฉลอง         สิชล  สุราษฎร์ธานี  8.899548
# 10111873  17:25:00  ท่าทองใหม่   กาญจนดิษฐ์  สุราษฎร์ธานี  9.174437
# 10111779  23:40:00     บางริ้น   เมืองระนอง         ระนอง  9.935354
# 10111864  23:40:00     บางริ้น   เมืองระนอง         ระนอง  9.935354
#
#             AccLong  ICD-10        Vehicle people
# id
# 8722010         NaN    V892   ไม่ระบุพาหนะ      1
# 8722006         NaN    V892   ไม่ระบุพาหนะ      1
# 8722013         NaN    V892   ไม่ระบุพาหนะ      1
# 8722017         NaN    V892   ไม่ระบุพาหนะ      1
# 8721975         NaN    V892   ไม่ระบุพาหนะ      1
# ...             ...     ...            ...    ...
# 10111398  98.336526     NaN  รถจักรยานยนต์      1
# 10112013  99.795811     NaN  รถจักรยานยนต์      1
# 10111873  99.397227     NaN  รถจักรยานยนต์      1
# 10111779  98.633255     NaN  รถจักรยานยนต์      1
# 10111864  98.633255     NaN  รถจักรยานยนต์      1
#
# [223545 rows x 22 columns]>

# %%
data.dtypes
# Out:
# DEAD_YEAR(Budha)             int64
# DEAD_YEAR                    int64
# Age                        float64
# Sex                        float64
# BirthYear                   object
# NationalityId              float64
# Tumbol                      object
# District                    object
# Province                    object
# RiskHelmet                 float64
# RiskSafetyBelt             float64
# DeadDate            datetime64[ns]
# DateRec             datetime64[ns]
# TimeRec                     object
# AccSubDist                  object
# AccDist                     object
# AccProv                     object
# AccLat                     float64
# AccLong                    float64
# ICD-10                      object
# Vehicle                     object
# people                       int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# DEAD_YEAR(Budha)         0
# DEAD_YEAR                0
# Age                  29665
# Sex                   5474
# BirthYear           207302
# NationalityId        97258
# Tumbol              189287
# District            144990
# Province            144835
# RiskHelmet          219155
# RiskSafetyBelt      221479
# DeadDate                 0
# DateRec             116595
# TimeRec             116595
# AccSubDist          118528
# AccDist             118065
# AccProv                  5
# AccLat              120509
# AccLong             120510
# ICD-10               52250
# Vehicle                  0
# people                   0
# dtype: int64

# %%
data['DeadDate'] = pd.to_datetime(data['DeadDate'],format = ('%Y%m%d'))
data = data.set_index(['DeadDate'])

# %%
data
# Out:
#             DEAD_YEAR(Budha)  DEAD_YEAR   Age  Sex BirthYear  NationalityId  \
# DeadDate
# 2016-02-07              2559       2016  47.0  1.0       NaN            NaN
# 2016-06-22              2559       2016  48.0  1.0       NaN            NaN
# 2016-04-27              2559       2016  48.0  1.0       NaN            NaN
# 2016-05-18              2559       2016  48.0  1.0       NaN            NaN
# 2016-10-18              2559       2016  49.0  1.0       NaN            NaN
# ...                      ...        ...   ...  ...       ...            ...
# 2019-06-29              2562       2019  33.0  NaN       NaN            NaN
# 2019-09-23              2562       2019  39.0  NaN       NaN            NaN
# 2019-10-06              2562       2019  77.0  NaN       NaN            NaN
# 2019-12-31              2562       2019   NaN  NaN       NaN            NaN
# 2019-12-31              2562       2019  15.0  NaN       NaN            NaN
#
#            Tumbol           District       Province  RiskHelmet  ...  \
# DeadDate                                                         ...
# 2016-02-07    NaN                NaN            NaN         NaN  ...
# 2016-06-22    NaN                NaN            NaN         NaN  ...
# 2016-04-27    NaN                NaN            NaN         NaN  ...
# 2016-05-18    NaN                NaN            NaN         NaN  ...
# 2016-10-18    NaN                NaN            NaN         NaN  ...
# ...           ...                ...            ...         ...  ...
# 2019-06-29    NaN        เมืองภูเก็ต         ภูเก็ต         NaN  ...
# 2019-09-23    NaN               สิชล  นครศรีธรรมราช         NaN  ...
# 2019-10-06    NaN  เมืองสุราษฎร์ธานี   สุราษฎร์ธานี         NaN  ...
# 2019-12-31    NaN         เมืองระนอง          ระนอง         NaN  ...
# 2019-12-31    NaN         เมืองระนอง          ระนอง         NaN  ...
#
#               DateRec   TimeRec  AccSubDist      AccDist       AccProv  \
# DeadDate
# 2016-02-07        NaT       NaN         NaN          NaN      พิษณุโลก
# 2016-06-22        NaT       NaN         NaN          NaN      พิษณุโลก
# 2016-04-27        NaT       NaN         NaN          NaN      พิษณุโลก
# 2016-05-18        NaT       NaN         NaN          NaN      พิษณุโลก
# 2016-10-18        NaT       NaN         NaN          NaN      พิษณุโลก
# ...               ...       ...         ...          ...           ...
# 2019-06-29 2019-06-29  20:30:00        ฉลอง  เมืองภูเก็ต        ภูเก็ต
# 2019-09-23 2019-09-23  14:20:00        ฉลอง         สิชล  สุราษฎร์ธานี
# 2019-10-06 2019-10-06  17:25:00  ท่าทองใหม่   กาญจนดิษฐ์  สุราษฎร์ธานี
# 2019-12-31 2019-12-31  23:40:00     บางริ้น   เมืองระนอง         ระนอง
# 2019-12-31 2019-12-31  23:40:00     บางริ้น   เมืองระนอง         ระนอง
#
#               AccLat    AccLong  ICD-10        Vehicle people
# DeadDate
# 2016-02-07       NaN        NaN    V892   ไม่ระบุพาหนะ      1
# 2016-06-22       NaN        NaN    V892   ไม่ระบุพาหนะ      1
# 2016-04-27       NaN        NaN    V892   ไม่ระบุพาหนะ      1
# 2016-05-18       NaN        NaN    V892   ไม่ระบุพาหนะ      1
# 2016-10-18       NaN        NaN    V892   ไม่ระบุพาหนะ      1
# ...              ...        ...     ...            ...    ...
# 2019-06-29  7.846704  98.336526     NaN  รถจักรยานยนต์      1
# 2019-09-23  8.899548  99.795811     NaN  รถจักรยานยนต์      1
# 2019-10-06  9.174437  99.397227     NaN  รถจักรยานยนต์      1
# 2019-12-31  9.935354  98.633255     NaN  รถจักรยานยนต์      1
# 2019-12-31  9.935354  98.633255     NaN  รถจักรยานยนต์      1
#
# [223545 rows x 21 columns]

# %%
data['people']
# Out:
# DeadDate
# 2016-02-07    1
# 2016-06-22    1
# 2016-04-27    1
# 2016-05-18    1
# 2016-10-18    1
#              ..
# 2019-06-29    1
# 2019-09-23    1
# 2019-10-06    1
# 2019-12-31    1
# 2019-12-31    1
# Name: people, Length: 223545, dtype: int64

# %%
y = data['people'].resample('MS').sum()
y
# Out:
# DeadDate
# 2011-01-01    2068
# 2011-02-01    1859
# 2011-03-01    1987
# 2011-04-01    1907
# 2011-05-01    1763
#               ...
# 2021-08-01    1173
# 2021-09-01    1118
# 2021-10-01    1277
# 2021-11-01    1504
# 2021-12-01    1756
# Freq: MS, Name: people, Length: 132, dtype: int64

# %%
#Import the libraries
import warnings

# %%
import itertools

# %%
import pandas_datareader as web
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\MISBAH~1\AppData\Local\Temp/ipykernel_15624/1744824549.py in <module>
# ----> 1 import pandas_datareader as web
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
import pandas as pd

# %%
import numpy as np

# %%
import statsmodels.api as sm

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
import pandas_datareader as web
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\MISBAH~1\AppData\Local\Temp/ipykernel_15624/1744824549.py in <module>
# ----> 1 import pandas_datareader as web
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
y.plot(figsize=(15, 6))
plt.show()

# %%
#Creating the training data set
p=d=q= range(0,2)
pdq = list(itertools.product(p,d,q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p,d,q))]
print('Examples of parameter combinations for seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1],seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1],seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2],seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2],seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
warnings.filterwarnings("ignore")

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,order=param,seasonal_order=param_seasonal,
                                           enforce_stationarity=False,
                                           enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param,param_seasonal,results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:2323.531550083604
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1969.9038845995747
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:1553.5203629271034
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:1392.7008783870772
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1557.9446711555127
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1517.5842232987272
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:1404.0968581946815
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:1393.0176505209915
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:2137.021659116007
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:1814.9136939364437
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:1511.6643853181208
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:1345.105697830198
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1530.2989676811276
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:1472.2669032677884
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:1371.077282943008
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:1345.6012866980911
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1692.1751171535907
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1517.019229225689
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:1517.8734646879657
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1324.786128443593
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:1507.2310563737176
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1469.39164551943
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:1351.2975489321382
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:1326.4539349737076
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1681.3720827783616
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:1502.3276693639195
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:1487.6401059910659
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1294.8270556480504
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:1498.037603828268
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1437.5684861274872
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:1330.1197151223587
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1296.3174463265045
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1707.325105897392
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1530.9750398534372
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:1504.6537693037787
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:1323.874222692032
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:1501.6680143469925
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1459.7208143665277
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:1333.6007135425675
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:1325.0620500235611
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1695.6580586598739
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:1518.5748747331781
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:1491.2025295297128
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:1305.1974004965489
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:1500.372037230793
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1443.6287042899771
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:1328.0867129808344
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:1306.4135534205398
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1693.9395137799097
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1516.344051613486
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:1504.1064212749934
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1310.9900710995212
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:1487.8917459676252
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1455.7746211760814
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:1325.329348735544
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:1312.4878288223122
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1668.9245184578294
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1490.624283375691
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:1483.168041969876
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1294.771753425854
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:1488.4592858312249
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1438.2205395363185
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:1319.1677868401666
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:1296.7136330791548

# %%
mod = sm.tsa.statespace.SARIMAX(y,order=(1,1,1),
                               seasonal_order =(1,1,1,12),
                               enforce_stationarity = False,
                               enforce_invertibility = False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3391      0.130      2.606      0.009       0.084       0.594
# ma.L1         -0.8140      0.091     -8.984      0.000      -0.992      -0.636
# ar.S.L12      -0.2331      0.237     -0.984      0.325      -0.697       0.231
# ma.S.L12      -0.6046      0.244     -2.474      0.013      -1.084      -0.126
# sigma2       1.19e+04    876.648     13.572      0.000    1.02e+04    1.36e+04
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(15,12))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2019-01-01'),dynamic=False)
pred_ci = pred.conf_int()

# %%
plt.figure(figsize=(15, 6))
ax = y['2011':].plot(label='observed')
pred.predicted_mean.plot(ax = ax,label='One-step ahead Forecast',alpha=.7)
ax.fill_between(pred_ci.index,pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1],color='k',alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Total dead')

plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2019-01-01':]

mse = ((y_forecasted - y_truth) **2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse,2)))
# Out:
# The Mean Squared Error of our forecasts is 21224.88

# %%
pred_dynamic = results.get_prediction(start=pd.to_datetime('2019-01-01'),dynamic=True, full_result=True)
pred_dynamic_ci = pred_dynamic.conf_int()

# %%
plt.figure(figsize=(15,6))
ax = y['2011':].plot(label='observed', figsize=(20, 15))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_ci.index,
                pred_dynamic_ci.iloc[:, 0],
                pred_dynamic_ci.iloc[:, 1], color='k', alpha=.25)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2019-01-01'), y.index[-1],
                 alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('Dead rate')
plt.legend()
plt.show()

# %%
# Extract the predicted and true values of our time series
y_forecasted = pred_dynamic.predicted_mean
y_truth = y['2019-01-01':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 31357.05

# %%
# Get forecast 500 steps ahead in future
pred_uc = results.get_forecast(steps=50)

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

# %%
ax = y.plot(label='observed', figsize=(20, 15))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Close Price')

plt.legend()
plt.show()
